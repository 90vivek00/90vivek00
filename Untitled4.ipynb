# %%
import cv2
from google.colab. patches import cv2_imshow
image=cv2.imread("/virat kohli.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1365>

# %%
from google.colab import drive
drive.mount('/content/drive')
